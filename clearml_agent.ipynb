# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/final_project/code/SA_Uet-pytorch-master/
# Out:
# /content/drive/MyDrive/final_project/code/SA_Uet-pytorch-master

# %%
# !nvidia-smi
# Out:
# Sat Aug 27 19:03:09 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install clearml numpy clearml-agent 'pyjwt<1.8.0'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting clearml
#   Downloading clearml-1.6.4-py2.py3-none-any.whl (925 kB)
#      |████████████████████████████████| 925 kB 14.7 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)
# Collecting clearml-agent
#   Downloading clearml_agent-1.3.0-py3-none-any.whl (373 kB)
#      |████████████████████████████████| 373 kB 69.6 MB/s
# Collecting pyjwt<1.8.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from clearml) (0.16.0)
# Requirement already satisfied: Pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from clearml) (7.1.2)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from clearml) (1.15.0)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.7/dist-packages (from clearml) (6.0)
# Requirement already satisfied: psutil>=3.4.2 in /usr/local/lib/python3.7/dist-packages (from clearml) (5.4.8)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from clearml) (1.24.3)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from clearml) (4.3.3)
# Requirement already satisfied: attrs>=18.0 in /usr/local/lib/python3.7/dist-packages (from clearml) (22.1.0)
# Collecting pathlib2>=2.3.0
#   Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from clearml) (2.8.2)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.7/dist-packages (from clearml) (3.0.9)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from clearml) (2.23.0)
# Collecting furl>=2.0.0
#   Downloading furl-2.1.3-py2.py3-none-any.whl (20 kB)
# Collecting clearml
#   Downloading clearml-1.6.3-py2.py3-none-any.whl (925 kB)
#      |████████████████████████████████| 925 kB 57.1 MB/s
#   Downloading clearml-1.6.2-py2.py3-none-any.whl (812 kB)
#      |████████████████████████████████| 812 kB 63.0 MB/s
#   Downloading clearml-1.6.1-py2.py3-none-any.whl (812 kB)
#      |████████████████████████████████| 812 kB 58.1 MB/s
#   Downloading clearml-1.6.0-py2.py3-none-any.whl (812 kB)
#      |████████████████████████████████| 812 kB 74.1 MB/s
#   Downloading clearml-1.5.0-py2.py3-none-any.whl (799 kB)
#      |████████████████████████████████| 799 kB 69.4 MB/s
#   Downloading clearml-1.4.1-py2.py3-none-any.whl (794 kB)
#      |████████████████████████████████| 794 kB 76.6 MB/s
# Collecting orderedmultidict>=1.0.1
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6.0->clearml) (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6.0->clearml) (4.12.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6.0->clearml) (5.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6.0->clearml) (4.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6.0->clearml) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->clearml) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->clearml) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->clearml) (2.10)
# Collecting PyYAML>=3.12
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 63.7 MB/s
# Collecting pyparsing>=2.0.3
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 6.5 MB/s
# Collecting pyhocon<0.4.0,>=0.3.38
#   Downloading pyhocon-0.3.59.tar.gz (116 kB)
#      |████████████████████████████████| 116 kB 73.6 MB/s
# Collecting virtualenv<21,>=16
#   Downloading virtualenv-20.16.3-py2.py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 44.7 MB/s
# Collecting jsonschema>=2.6.0
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.0 MB/s
# Collecting attrs>=18.0
#   Downloading attrs-20.3.0-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.7 MB/s
# Collecting clearml-agent
#   Downloading clearml_agent-1.2.3-py3-none-any.whl (371 kB)
#      |████████████████████████████████| 371 kB 75.3 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6.0->clearml) (57.4.0)
# Collecting platformdirs<3,>=2.4
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Collecting distlib<1,>=0.3.5
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 55.8 MB/s
# Requirement already satisfied: filelock<4,>=3.4.1 in /usr/local/lib/python3.7/dist-packages (from virtualenv<21,>=16->clearml-agent) (3.8.0)
# Building wheels for collected packages: pyhocon
#   Building wheel for pyhocon (setup.py) ... done
#   Created wheel for pyhocon: filename=pyhocon-0.3.59-py3-none-any.whl size=19968 sha256=9ed6193bd99c8abfdf9ca04655ce1cba8ab5b997ce3ac8c4a8a10aa2869f151a
#   Stored in directory: /root/.cache/pip/wheels/69/f4/73/2afd609de4a040ee997bb9026d145e626124bc3ce8e5c23f79
# Successfully built pyhocon
# Installing collected packages: pyparsing, platformdirs, orderedmultidict, distlib, attrs, virtualenv, PyYAML, pyjwt, pyhocon, pathlib2, jsonschema, furl, clearml-agent, clearml
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.3.3
#     Uninstalling jsonschema-4.3.3:
#       Successfully uninstalled jsonschema-4.3.3
# Successfully installed PyYAML-5.4.1 attrs-20.3.0 clearml-1.4.1 clearml-agent-1.2.3 distlib-0.3.6 furl-2.1.3 jsonschema-3.2.0 orderedmultidict-1.0.1 pathlib2-2.3.7.post1 platformdirs-2.5.2 pyhocon-0.3.59 pyjwt-1.7.1 pyparsing-2.4.7 virtualenv-20.16.3

# %%
# %%bash
#
# export api=`cat <<EOF
# api {
#     # Nadav Potasman's workspace
#     web_server: https://app.clear.ml
#     api_server: https://api.clear.ml
#     files_server: https://files.clear.ml
#     credentials {
#         "access_key" = "N4KZ1J51HJ2SRNSYMU3A"
#         "secret_key" = "kwHW6KaSZqCud3sEsCkUpnuPjqUQJIP1RRv7db8esz3BifDUu0"
#     }
# }
# EOF
# `
# echo "$api" > /root/clearml.conf

# %%
# !clearml-agent daemon --queue default
# Out:
# Current configuration (clearml_agent v1.2.3, location: /root/clearml.conf):
# ----------------------
# sdk.storage.cache.default_base_dir = ~/.clearml/cache
# sdk.storage.cache.size.min_free_bytes = 10GB
# sdk.storage.direct_access.0.url = file://*
# sdk.metrics.file_history_size = 100
# sdk.metrics.matplotlib_untitled_history_size = 100
# sdk.metrics.images.format = JPEG
# sdk.metrics.images.quality = 87
# sdk.metrics.images.subsampling = 0
# sdk.metrics.tensorboard_single_series_per_graph = false
# sdk.network.metrics.file_upload_threads = 4
# sdk.network.metrics.file_upload_starvation_warning_sec = 120
# sdk.network.iteration.max_retries_on_server_error = 5
# sdk.network.iteration.retry_backoff_factor_sec = 10
# sdk.aws.s3.key =
# sdk.aws.s3.region =
# sdk.aws.boto3.pool_connections = 512
# sdk.aws.boto3.max_multipart_concurrency = 16
# sdk.log.null_log_propagate = false
# sdk.log.task_log_buffer_capacity = 66
# sdk.log.disable_urllib3_info = true
# sdk.development.task_reuse_time_window_in_hours = 72.0
# sdk.development.vcs_repo_detect_async = true
# sdk.development.store_uncommitted_code_diff = true
# sdk.development.support_stopping = true
# sdk.development.default_output_uri =
# sdk.development.force_analyze_entire_repo = false
# sdk.development.suppress_update_message = false
# sdk.development.detect_with_pip_freeze = false
# sdk.development.worker.report_period_sec = 2
# sdk.development.worker.ping_period_sec = 30
# sdk.development.worker.log_stdout = true
# sdk.development.worker.report_global_mem_used = false
# api.version = 1.5
# api.verify_certificate = true
# api.default_version = 1.5
# api.http.max_req_size = 15728640
# api.http.retries.total = 240
# api.http.retries.connect = 240
# api.http.retries.read = 240
# api.http.retries.redirect = 240
# api.http.retries.status = 240
# api.http.retries.backoff_factor = 1.0
# api.http.retries.backoff_max = 120.0
# api.http.wait_on_maintenance_forever = true
# api.http.pool_maxsize = 512
# api.http.pool_connections = 512
# api.web_server = https://app.clear.ml
# api.api_server = https://api.clear.ml
# api.files_server = https://files.clear.ml
# api.credentials.access_key = N4KZ1J51HJ2SRNSYMU3A
# api.host = https://api.clear.ml
# agent.worker_id =
# agent.worker_name = b957faa618d1
# agent.force_git_ssh_protocol = false
# agent.python_binary =
# agent.package_manager.type = pip
# agent.package_manager.pip_version = <20.2
# agent.package_manager.system_site_packages = false
# agent.package_manager.force_upgrade = false
# agent.package_manager.conda_channels.0 = pytorch
# agent.package_manager.conda_channels.1 = conda-forge
# agent.package_manager.conda_channels.2 = defaults
# agent.package_manager.torch_nightly = false
# agent.venvs_dir = /root/.clearml/venvs-builds
# agent.venvs_cache.max_entries = 10
# agent.venvs_cache.free_space_threshold_gb = 2.0
# agent.vcs_cache.enabled = true
# agent.vcs_cache.path = /root/.clearml/vcs-cache
# agent.venv_update.enabled = false
# agent.pip_download_cache.enabled = true
# agent.pip_download_cache.path = /root/.clearml/pip-download-cache
# agent.translate_ssh = true
# agent.reload_config = false
# agent.docker_pip_cache = /root/.clearml/pip-cache
# agent.docker_apt_cache = /root/.clearml/apt-cache
# agent.docker_force_pull = false
# agent.default_docker.image = nvidia/cuda:10.2-cudnn7-runtime-ubuntu18.04
# agent.enable_task_env = false
# agent.hide_docker_command_env_vars.enabled = true
# agent.hide_docker_command_env_vars.parse_embedded_urls = true
# agent.docker_internal_mounts.sdk_cache = /clearml_agent_cache
# agent.docker_internal_mounts.apt_cache = /var/cache/apt/archives
# agent.docker_internal_mounts.ssh_folder = /root/.ssh
# agent.docker_internal_mounts.pip_cache = /root/.cache/pip
# agent.docker_internal_mounts.poetry_cache = /root/.cache/pypoetry
# agent.docker_internal_mounts.vcs_cache = /root/.clearml/vcs-cache
# agent.docker_internal_mounts.venv_build = /root/.clearml/venvs-builds
# agent.docker_internal_mounts.pip_download = /root/.clearml/pip-download-cache
# agent.apply_environment = true
# agent.apply_files = true
# agent.custom_build_script =
# agent.default_python = 3.7
# agent.cuda_version = 111
# agent.cudnn_version = 0
#
# Worker "b957faa618d1:gpuall" - Listening to queues:
# +----------------------------------+---------+-------+
# | id                               | name    | tags  |
# +----------------------------------+---------+-------+
# | 5c75230d27fb4fce83122153b6d4f66e | default |       |
# +----------------------------------+---------+-------+
#
# Running CLEARML-AGENT daemon in background mode, writing stdout/stderr to /tmp/.clearml_agent_daemon_outxhkzqyna.txt
