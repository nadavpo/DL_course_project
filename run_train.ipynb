# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/final_project/code/SA_Uet-pytorch-master/
# Out:
# /content/drive/MyDrive/final_project/code/SA_Uet-pytorch-master

# %%
base_path = "/content/drive/MyDrive/final_project/code/SA_Uet-pytorch-master/"

# %%
# !nvidia-smi
# Out:
# Wed Aug 24 18:31:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python train.py
# Out:
# Epoch[1/150]-train,train_loss:0.6165980100631714: 100% 45/45 [00:46<00:00,  1.02s/it]
# epoch: 1
# train_loss: 0.7321108645863004
# 100% 20/20 [00:12<00:00,  1.58it/s]
# Precision: 0.12333197146654129
# acc: 0.7978493571281433
# F1-score: 0.21342598731457937
# AUC_ROC: 0.9103207061384028
# Epoch[2/150]-train,train_loss:0.4840269088745117: 100% 45/45 [00:11<00:00,  3.77it/s]
# epoch: 2
# train_loss: 0.5455682317415873
# 100% 20/20 [00:01<00:00, 13.82it/s]
# Precision: 0.13388243317604065
# acc: 0.8678514361381531
# F1-score: 0.23218700051750663
# AUC_ROC: 0.9047739795732538
# Epoch[3/150]-train,train_loss:0.37301555275917053: 100% 45/45 [00:11<00:00,  3.77it/s]
# epoch: 3
# train_loss: 0.4261327730284797
# 100% 20/20 [00:01<00:00, 13.78it/s]
# Precision: 0.10756193101406097
# acc: 0.9715003967285156
# F1-score: 0.19423059463619438
# AUC_ROC: 0.9126330741222946
# Epoch[4/150]-train,train_loss:0.28422972559928894: 100% 45/45 [00:11<00:00,  3.76it/s]
# epoch: 4
# ...

# %%
# !pip install torch==1.8.1 torchvision==0.9.1 ninja
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 804.1 MB 1.8 kB/s
# ...
#      |████████████████████████████████| 17.4 MB 89 kB/s
# ...
#      |████████████████████████████████| 108 kB 89.3 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.0+cu113
#     Uninstalling torch-1.12.0+cu113:
#       Successfully uninstalled torch-1.12.0+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.0+cu113
#     Uninstalling torchvision-0.13.0+cu113:
#       Successfully uninstalled torchvision-0.13.0+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.0 requires torch==1.12.0, but you have torch 1.8.1 which is incompatible.
# ...

# %%
! python train.py --outdir="/content/drive/MyDrive/final_project/code/stylegan2-ada-pytorch-main/training-runs" --data="/content/drive/MyDrive/final project/code/stylegan2-ada-pytorch-main/datasets/28_training_fix.zip" --gpus=1 --resume=ffhq512 --mirror=1 --workers=2 --snap=20

# %%
import torch
torch.__version__
# Out:
# '1.8.1+cu102'

# %%
data_path = r"/content/drive/MyDrive/final_project/code/stylegan2-ada-pytorch-main/datasets/28_training_x_flip_jitter_rotate_fix.zip"
gpus=1
resume_net_path = r"/content/drive/MyDrive/final_project/code/stylegan2-ada-pytorch-main/training-runs/00028-28_training_x_flip_jitter_rotate_fix-auto1-resumecustom/network-snapshot-000204.pkl"
snap_interval = 25
allow_mirror = 0
output_dir = r"/content/drive/MyDrive/final_project/code/stylegan2-ada-pytorch-main/training-runs"
metrics = "fid50k"

# !python train.py --outdir={output_dir} --data={data_path} --gpus={gpus} --resume={resume_net_path} --mirror={allow_mirror} --workers=2 --snap={snap_interval} --metrics={metrics}
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 25,
#   "network_snapshot_ticks": 25,
#   "metrics": [
#     "fid50k"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/final_project/code/stylegan2-ada-pytorch-main/datasets/28_training_x_flip_jitter_rotate_fix.zip",
#     "use_labels": false,
#     "max_size": 2080,
#     "xflip": false,
#     "resolution": 512
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 2,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
# ...
