# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/final_project/code/SA_Uet-pytorch-master/
# Out:
# /content/drive/MyDrive/final_project/code/SA_Uet-pytorch-master

# %%
# !nvidia-smi
# Out:
# Wed Aug 31 19:23:18 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python train.py --lr=0.0001 --data-path=./DRIVE/gan_aug --fine-tune-path=./DRIVE/aug_training --test-path=./DRIVE/test --exp-name=gan_aug_with_FT

# %%
# !python inferance.py --input_dir=./DRIVE/gan_data/images --output_dir=./DRIVE/gan_data/1st_manual --model_path=./results/base_model/best_model.pth
# Out:
# computing mean std...
# mean - [0.4863596, 0.26184077, 0.14925525]
# std - [0.34434437, 0.18728918, 0.10615013]
# loading model...
# 1001 images found. starting inference
# 100% 1001/1001 [00:40<00:00, 24.73it/s]
